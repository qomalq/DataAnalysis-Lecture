# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
tip = sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip['팁의 비율'] = tip['tip'] / tip['total_bill']*100
tip.pivot_table('팁의 비율', 'day')
# Out:
#           팁의 비율
# day
# Thur  16.127563
# Fri   16.991303
# Sat   15.315172
# Sun   16.689729

# %%
x , y = tip['day'] , tip['팁의 비율']
plt.title('요일별 팁의 비율')
plt.bar(x,y)
plt.xlabel('요일')
plt.ylabel('팁의 비율')
plt.show()

# %%
plt.figure(figsize=(5,3))

# %%
ans = sns.load_dataset('anscombe')
ans1 = ans[0:11]
ans2 = ans[11:22]
ans3 = ans[22:33]
ans4 = ans[33:]

# %%
for roman in ['I','II','III','IV']:
    ds = ans[ans.dataset == roman]
    plt.figure(figsize=(3,2))
    plt.scatter(ds.x,ds.y,marker='o')
    plt.plot([3,20],[4.5,13],'r-')

# %%
fig, axes = plt.subplots(2,2)
x = [ans1.x]
y = [ans1.y]
axes[0][0].scatter(x,y)
x = [ans2.x]
y = [ans2.y]
axes[0][1].scatter(x,y)
x = [ans3.x]
y = [ans3.y]
axes[1][0].scatter(x,y)
x = [ans4.x]
y = [ans4.y]
axes[1][1].scatter(x,y)
plt.show()

# %%
cctv = pd.read_csv('data/cctv.csv')
cctv = cctv[['구별','CCTV댓수']]

# %%
cctv.set_index('구별',inplace=True)
cctv
# Out:
#       CCTV댓수
# 구별
# 종로구     1980
# 중구      2584
# 용산구     2847
# 성동구     4047
# 광진구     3480
# 동대문구    2759
# 중랑구     4193
# 성북구     4842
# 강북구     3321
# 도봉구     2247
# 노원구     2617
# 은평구     4653
# 서대문구    3445
# 마포구     2628
# 양천구     3851
# 강서구     3265
# 구로구     4693
# 금천구     2636
# 영등포구    4553
# 동작구     2671
# 관악구     5398
# 서초구     4995
# 강남구     7243
# 송파구     3203
# 강동구     3190

# %%
plt.barh(cctv.index, cctv['CCTV댓수'])
plt.title('서울시 구별 CCTV 댓수')
plt.show()

# %%
si = cctv.CCTV댓수.sort_index(ascending=False)
plt.barh(si.index,si.values )
plt.title('서울시 구별 CCTV 댓수')
plt.show()

# %%
sv = cctv.CCTV댓수.sort_values()
plt.barh(sv.index, sv.values)
plt.title('서울시 구별 CCTV 댓수')
plt.show()
