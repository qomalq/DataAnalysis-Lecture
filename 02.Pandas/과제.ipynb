# %%
import numpy as np
import pandas as pd
filename = 'data/서울시 자치구 년도별 CCTV 설치 현황_221231기준.csv'
cctv = pd.read_csv(filename, encoding='euc-kr',thousands=',')
columns = '구별,CCTV댓수,2013년 이전설치된 CCTV,2013년,2014년,2015년,2016년,2017년,2018년,2019년,2020년,2021년,2022년'.split(',')
            #구분 -> 구별 / 총계 -> CCTV댓수
cctv = cctv[columns]
cctv.head()
# Out:
#     구별  CCTV댓수  2013년 이전설치된 CCTV  2013년  2014년  2015년  2016년  2017년  2018년
# 0    계   91341              2804   3097   3981   6576   8850  11566  11024  \
# 1  종로구    1980                36    540    107    161    131    158    152
# 2  중 구    2584               130     87     77    236    240    372    386
# 3  용산구    2847                44     50     68     83    295    491    115
# 4  성동구    4047                58     99    110    366    279    945    459
#
#    2019년  2020년  2021년  2022년
# 0  13151  11912   9144   9236
# 1     69    250     85    291
# 2    155    361    403    137
# 3    322    623    422    334
# 4    647    485    367    232

# %%
# 첫번째 행 계 삭제
cctv.drop([0], axis=0, inplace=True)
cctv.head()
# Out:
#     구별  CCTV댓수  2013년 이전설치된 CCTV  2013년  2014년  2015년  2016년  2017년  2018년
# 1  종로구    1980                36    540    107    161    131    158    152  \
# 2  중 구    2584               130     87     77    236    240    372    386
# 3  용산구    2847                44     50     68     83    295    491    115
# 4  성동구    4047                58     99    110    366    279    945    459
# 5  광진구    3480               507     82     84     64     21    465    443
#
#    2019년  2020년  2021년  2022년
# 1     69    250     85    291
# 2    155    361    403    137
# 3    322    623    422    334
# 4    647    485    367    232
# 5    709    172    662    271

# %%
# 최근증가율 = 최근 3개년 cctv댓수의 합 / 이전 모든 년도의 CCTV 댓수
rec1 = cctv['2020년,2021년,2022년'.split(',')]
rec2 = cctv['2013년 이전설치된 CCTV,2013년,2014년,2015년,2016년,2017년,2018년,2019년'.split(',')]
rec1['3개년 합'] = rec1.sum(axis=1)
rec2['그 이전 모든 년도의 합'] = rec2.sum(axis=1)
# rec1['3개년 합'] = (cctv['2020년'] + cctv['2021년'] + cctv['2022년'])
# Out:
# C:\Users\YONSAI\AppData\Local\Temp\ipykernel_10848\3487578049.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec1['3개년 합'] = rec1.sum(axis=1)
# C:\Users\YONSAI\AppData\Local\Temp\ipykernel_10848\3487578049.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec2['그 이전 모든 년도의 합'] = rec2.sum(axis=1)

# %%
cctv['최근증가율'] = (rec1['3개년 합'] / rec2['그 이전 모든 년도의 합']).round(2) *100

# %%
cctv[['CCTV댓수','최근증가율',]]
# Out:
#     CCTV댓수  최근증가율
# 1     1980   46.0
# 2     2584   54.0
# 3     2847   94.0
# 4     4047   37.0
# 5     3480   47.0
# 6     2759   34.0
# 7     4193   74.0
# 8     4842   26.0
# 9     3321  100.0
# 10    2247  156.0
# 11    2617   41.0
# 12    4653   38.0
# 13    3445   59.0
# 14    2628   29.0
# 15    3851   36.0
# 16    3265   71.0
# 17    4693   51.0
# 18    2636   61.0
# 19    4553   82.0
# 20    2671   44.0
# 21    5398   26.0
# 22    4995   60.0
# 23    7243   36.0
# 24    3203   29.0
# 25    3190   75.0

# %%
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 2. 서울시 인구 데이터를 다음과 같이 만들어 pop.csv 파일에 저장하세요.

# %% [markdown]
#   구별     인구수  내국인  외국인  고령자  외국인비율  고령자비율
#
# 1 종로구 153789 144683  9106    27818   5.92           18.09
#
# 2 중구    131787 122499  9288    24392   7.05           18.51
#
# 3 용산구 237285 222953  14332   39070   6.04           16.47

# %%
df = pd.read_csv('data/서울시인구.txt', sep='\t', encoding='utf-8',thousands=',')
df.head()
# Out:
#      기간  자치구         세대         인구       인구.1       인구.2       인구.3
# 0    기간  자치구         세대         합계         합계         합계        한국인  \
# 1    기간  자치구         세대          계         남자         여자          계
# 2  2021   합계  4,426,007  9,736,027  4,721,977  5,014,050  9,509,458
# 3  2021  종로구     73,494    153,789     74,186     79,603    144,683
# 4  2021   중구     63,519    131,787     64,083     67,704    122,499
#
#         인구.4       인구.5     인구.6     인구.7     인구.8  세대당인구   65세이상고령자
# 0        한국인        한국인    등록외국인    등록외국인    등록외국인  세대당인구   65세이상고령자
# 1         남자         여자        계       남자       여자  세대당인구   65세이상고령자
# 2  4,618,040  4,891,418  226,569  103,937  122,632   2.15  1,605,416
# 3     70,183     74,500    9,106    4,003    5,103   1.97     27,818
# 4     59,630     62,869    9,288    4,453    4,835   1.93     24,392

# %%
# 불필요한 행열 삭제
df.drop([1], axis=0, inplace=True)
df.drop([2], axis=0, inplace=True)
df.drop(['기간'], axis=1, inplace=True)
df.drop(['세대'], axis=1, inplace=True)
df.head()
# Out:
#    자치구       인구     인구.1     인구.2     인구.3     인구.4     인구.5    인구.6   인구.7
# 0  자치구       합계       합계       합계      한국인      한국인      한국인   등록외국인  등록외국인  \
# 3  종로구  153,789   74,186   79,603  144,683   70,183   74,500   9,106  4,003
# 4   중구  131,787   64,083   67,704  122,499   59,630   62,869   9,288  4,453
# 5  용산구  237,285  115,085  122,200  222,953  107,210  115,743  14,332  7,875
# 6  성동구  292,672  142,259  150,413  285,990  139,380  146,610   6,682  2,879
#
#     인구.8  세대당인구  65세이상고령자
# 0  등록외국인  세대당인구  65세이상고령자
# 3  5,103   1.97    27,818
# 4  4,835   1.93    24,392
# 5  6,457   2.01    39,070
# 6  3,803   2.13    46,380

# %%
# 외국인 비율 열 추가
df['외국인 비율'] = (df['인구.6'] / df['인구']) * 100
df['고령자비율'] = (df['65세이상고령자'] / df['인구']) * 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:164, in _na_arithmetic_op(left, right, op, is_cmp)
#     163 try:
# --> 164     result = func(left, right)
#     165 except TypeError:
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[154], line 2
#       1 # 외국인 비율 열 추가
# ----> 2 df['외국인 비율'] = (df['인구.6'] / df['인구']) * 100
#       3 df['고령자비율'] = (df['65세이상고령자'] / df['인구']) * 100
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\series.py:6113, in Series._arith_method(self, other, op)
#    6111 def _arith_method(self, other, op):
#    6112     self, other = ops.align_method_SERIES(self, other)
# -> 6113     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:225, in arithmetic_op(left, right, op)
#     221     _bool_arith_check(op, left, right)
#     223     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     224     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 225     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     227 return res_values
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     165 except TypeError:
#     166     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     167         # For object dtype, fallback to a masked operation (only operating
#     168         #  on the non-missing values)
#     169         # Don't do this for comparisons, as that will handle complex numbers
#     170         #  incorrectly, see GH#32047
# --> 171         result = _masked_arith_op(left, right, op)
#     172     else:
#     173         raise
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:109, in _masked_arith_op(x, y, op)
#     107     # See GH#5284, GH#5035, GH#19448 for historical reference
#     108     if mask.any():
# --> 109         result[mask] = op(xrav[mask], yrav[mask])
#     111 else:
#     112     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
# Out:
# 0      등록외국인
# 1          계
# 3      9,106
# 4      9,288
# 5     14,332
# 6      6,682
# 7     12,631
# 8     14,606
# 9      4,535
# 10     9,614
# 11     3,381
# 12     2,007
# 13     3,990
# 14     3,866
# 15    10,840
# 16     9,781
# 17     3,185
# 18     5,453
# 19    24,409
# 20    14,080
# 21    24,071
# 22     8,881
# 23    13,750
# 24     3,888
# 25     4,758
# 26     5,627
# 27     3,808
# Name: 인구.6, dtype: object
