# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('data/유튜브랭킹.csv')
df.head()
# Out:
#    순위      카테고리                채널명      구독자수          조회수   영상수
# 0   1  음악/댄스/가수          BLACKPINK  87300000  30533500000   507
# 1   2  음악/댄스/가수          BANGTANTV  74500000  20143000000  2188
# 2   3  음악/댄스/가수        HYBE LABELS  70300000  27323160000  1158
# 3   4  음악/댄스/가수             SMTOWN  31600000  26794810000  4110
# 4   5  음악/댄스/가수  JYP Entertainment  26800000  19275070000  1668

# %% [markdown]
# - 구독자수 top20 - barh 차트로

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#        순위       카테고리                채널명      구독자수          조회수   영상수
# 0       1   음악/댄스/가수          BLACKPINK  87300000  30533500000   507
# 1       2   음악/댄스/가수          BANGTANTV  74500000  20143000000  2188
# 2       3   음악/댄스/가수        HYBE LABELS  70300000  27323160000  1158
# 3       4   음악/댄스/가수             SMTOWN  31600000  26794810000  4110
# 4       5   음악/댄스/가수  JYP Entertainment  26800000  19275070000  1668
# ..    ...        ...                ...       ...          ...   ...
# 995   991     회사/오피셜           LG Uplus    730000   1379980000  2473
# 996   998  BJ/인물/연예인                 케이    730000    572670000  3304
# 997  1001        미분류           백크 Baekk    720000    457320000  1106
# 998   999   음악/댄스/가수              Crush    720000    395460000   131
# 999   997  BJ/인물/연예인   bobaepapa - 보배아빠    720000    348440000   393
#
# [1000 rows x 6 columns]

# %%
df.set_index('채널명',inplace=True)

# %%
df
# Out:
#                      순위       카테고리      구독자수          조회수   영상수
# 채널명
# BLACKPINK             1   음악/댄스/가수  87300000  30533500000   507
# BANGTANTV             2   음악/댄스/가수  74500000  20143000000  2188
# HYBE LABELS           3   음악/댄스/가수  70300000  27323160000  1158
# SMTOWN                4   음악/댄스/가수  31600000  26794810000  4110
# JYP Entertainment     5   음악/댄스/가수  26800000  19275070000  1668
# ...                 ...        ...       ...          ...   ...
# LG Uplus            991     회사/오피셜    730000   1379980000  2473
# 케이                  998  BJ/인물/연예인    730000    572670000  3304
# 백크 Baekk           1001        미분류    720000    457320000  1106
# Crush               999   음악/댄스/가수    720000    395460000   131
# bobaepapa - 보배아빠    997  BJ/인물/연예인    720000    348440000   393
#
# [1000 rows x 5 columns]

# %%
df =df['구독자수'].sort_values(ascending=False)
df
# Out:
# 채널명
# BLACKPINK                87300000
# BANGTANTV                74500000
# HYBE LABELS              70300000
# SMTOWN                   31600000
# JYP Entertainment        26800000
#                            ...
# Conversational Korean      730000
# 버미쌤                        730000
# 백크 Baekk                   720000
# Crush                      720000
# bobaepapa - 보배아빠           720000
# Name: 구독자수, Length: 1000, dtype: int64

# %%
df = df.head(20)

df
# Out:
# 채널명
# BLACKPINK                            87300000
# BANGTANTV                            74500000
# HYBE LABELS                          70300000
# SMTOWN                               31600000
# JYP Entertainment                    26800000
# Boram Tube Vlog [보람튜브 브이로그]          26500000
# 1MILLION Dance Studio                26000000
# 1theK (원더케이)                         24500000
# Mnet K-POP                           20500000
# KBS WORLD TV                         18800000
# officialpsy                          18000000
# Jane ASMR 제인                         17600000
# JFlaMusic                            17600000
# TWICE                                15700000
# BIGBANG                              15000000
# Hongyu ASMR 홍유                       14900000
# Boram Tube ToysReview [보람튜브 토이리뷰]    14500000
# 서은일상이야기                              13900000
# BIBO와 장난감                            12900000
# Stray Kids                           12400000
# Name: 구독자수, dtype: int64

# %% [markdown]
# #### 구독자수 Top 20

# %%
dt = df.sort_values()
plt.barh(dt.index, dt.values)
plt.title('Top20 구독자수')
plt.show()

# %%
df2 = pd.read_csv('data/유튜브랭킹.csv')
df2 = pd.DataFrame(df2)
df2.set_index('채널명',inplace=True)
df2 =df2['조회수'].sort_values(ascending=False)
df2 = df2.head(20)
df2
# Out:
# 채널명
# BLACKPINK                      30533500000
# HYBE LABELS                    27323160000
# SMTOWN                         26794810000
# 1theK (원더케이)                   23634050000
# BANGTANTV                      20143000000
# JYP Entertainment              19275070000
# MBCentertainment               16816140000
# KBS WORLD TV                   14840730000
# Mnet K-POP                     14645400000
# JTBC Entertainment             11637980000
# Mnet TV                        11530740000
# Boram Tube Vlog [보람튜브 브이로그]    11052880000
# YTN                            10772940000
# officialpsy                    10522470000
# MBCNEWS                        10315200000
# Stone Music Entertainment       9386300000
# tvN D ENT                       9296540000
# KBS Entertain                   9059250000
# MBCkpop                         8850200000
# SBS Entertainment               8668180000
# Name: 조회수, dtype: int64

# %%
plt.barh(dt2.index, dt2.values)
plt.title('Top20 조회수')
plt.show()

# %%
df3 = pd.read_csv('data/유튜브랭킹.csv')
df3 = pd.DataFrame(df3)
df3.set_index('채널명',inplace=True)
df3 =df3['영상수'].sort_values(ascending=False)
df3 = df3.head(20)
df3
# Out:
# 채널명
# YTN                   671731
# 연합뉴스TV                458517
# SBS Drama             345476
# KBS News              247302
# SBS Entertainment     226145
# MBCNEWS               181391
# SBS 뉴스                168826
# JTBC News             164729
# MBN News              144240
# KBS Drama             129399
# KBS Entertain         116703
# MBCentertainment       97025
# 뉴스TVCHOSUN             85682
# SBS STORY              83975
# TVCHOSUN - TV조선        83868
# 채널A 뉴스                 83655
# JTBC Entertainment     78000
# tvN                    77936
# MTN 머니투데이방송            69790
# KBS 교양                 69698
# Name: 영상수, dtype: int64

# %%
plt.barh(dt3.index, dt3.values)
plt.title('Top20 영상수')
plt.show()

# %%
df4 = pd.read_csv('data/유튜브랭킹.csv')

# %%
df4.pivot_table('채널명','카테고리',aggfunc='count').sort_values('채널명',ascending=False)
# Out:
#            채널명
# 카테고리
# 미분류        181
# 음악/댄스/가수   155
# 키즈/어린이     132
# TV/방송      125
# 음식/요리/레시피   71
# BJ/인물/연예인   61
# 뉴스/정치/사회    59
# 게임          51
# 취미/라이프      31
# 영화/만화/애니    30
# 패션/미용       24
# 교육/강의       21
# 애완/반려동물     16
# 스포츠/운동       9
# 주식/경제/부동산    8
# IT/기술/컴퓨터    7
# 회사/오피셜       7
# 국내/해외/여행     5
# 해외           5
# 자동차          2

# %%
sns.barplot(y=df4.index[:10],x='count')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[391], line 1
# ----> 1 sns.barplot(y=df4.index,x='count')
#
# File c:\Users\YONSAI\anaconda3\lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# ...

# %%
df5 = df.pivot_table('구독자수','카테고리',aggfunc='sum').sort_values('구독자수',ascending=False)
df5.head(10)
# Out:
#                 구독자수
# 카테고리
# 음악/댄스/가수   818080000
# 키즈/어린이     402090000
# TV/방송      267760000
# 미분류        249330000
# 음식/요리/레시피  215100000
# 뉴스/정치/사회   102500000
# BJ/인물/연예인  102290000
# 게임          67350000
# 취미/라이프      49700000
# 영화/만화/애니    43950000

# %%
sns.barplot(y=df5.index[:10],x=df5.구독자수.head(10))
plt.title('카테고리별 구독자수')
# Out:
# Text(0.5, 1.0, '카테고리별 구독자수')
